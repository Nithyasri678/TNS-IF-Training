# %% [markdown]
# <a href="https://colab.research.google.com/github/Nithyasri678/TNS-IF-Training/blob/main/function1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def display():
  print("Nithyasri")
  print("Arumugasamy")

display()
# Out:
# Nithyasri
# Arumugasamy

# %% [markdown]
# def hi(num1,num2):
#   s=num1+num2
#   return s
# hi(2,3)

# %%
def hi(n1,n2):
  s=n1+n2
  return s
hi(1,2)
# Out:
# 3

# %%
import math
def area(r):
  a=2*math.pi*r
  print(a)
  print(round(a))
  print(round(a,3))
r=int(input("Enter radius of circle:"))
area(r)
# Out:
# Enter radius of circle:12
# 75.39822368615503
# 75
# 75.398

# %%
 0.
